# %%
# %env HV_DOC_HTML=True
# Out:
# env: HV_DOC_HTML=True

# %%
pip install -q holoviews
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -q hvplot
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f1df3ea1-5c13-486e-b3b4-c4e99e99cffc'>
#   <div id="f96570ab-fb17-44e9-b36f-569c14b0398e" data-root-id="f1df3ea1-5c13-486e-b3b4-c4e99e99cffc" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(r"Module 19 Challenge - Due 03-13-2025\Starter_Code\Resources\crypto_market_data.csv", index_col=['coin_id'])

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
scaledData = StandardScaler().fit_transform(df_market_data)

# %%
# Create a DataFrame with the scaled data
scaldedMarketData_df = pd.DataFrame(scaledData, columns=df_market_data.columns)

# Copy the crypto names from the original data
scaldedMarketData_df['coin_id'] = df_market_data.index

# Set the coinid column as index
scaldedMarketData_df = scaldedMarketData_df.set_index('coin_id')

# Display sample data
scaldedMarketData_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Data.

# %%
# Create a list with the number of k-values from 1 to 11
kValues = list(range(1,11))

# %%
# Create an empty list to store the inertia values
inertiaValues = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list
for k in kValues:
    model = KMeans(n_clusters=k, random_state=0, n_init='auto')
    model.fit(scaldedMarketData_df)
    inertiaValues.append(model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbowData = {
    "k": kValues,
    "inertia": inertiaValues
}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df = pd.DataFrame(elbowData)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
hvplot.extension('bokeh')
elbowPlot = elbow_df.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve",
    xticks=kValues
)

elbowPlot
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='907ac467-dd8a-45f9-8d22-a9cd8022d81e'>
#   <div id="ff7959aa-3e65-4116-90d6-edb5484a991c" data-root-id="907ac467-dd8a-45f9-8d22-a9cd8022d81e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:**

# %% [markdown]
# THe best value of k is "4".

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Data

# %%
# Initialize the K-Means model using the best value for k
kModel = KMeans(n_clusters=4, n_init='auto')

# %%
# Fit the K-Means model using the scaled data
kModel.fit(scaldedMarketData_df)
# Out:
# KMeans(n_clusters=4)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
cryptoPredictions = kModel.predict(scaldedMarketData_df)

# Print the resulting array of cluster values.
cryptoPredictions
# Out:
# array([3, 3, 0, 0, 3, 3, 3, 3, 3, 0, 0, 0, 0, 3, 0, 3, 0, 0, 3, 0, 0, 3,
#        0, 0, 0, 0, 0, 0, 3, 0, 0, 0, 1, 3, 0, 0, 2, 0, 0, 0, 0],
#       dtype=int32)

# %%
# Create a copy of the DataFrame
scaldedMarketData_df_predictions = scaldedMarketData_df.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
scaldedMarketData_df_predictions['cryptoCluster'] = cryptoPredictions

# Display sample data
scaldedMarketData_df_predictions.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
hvplot.extension('bokeh')

clusterPlot = scaldedMarketData_df_predictions.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="cryptoCluster",
    hover_cols=["coin_id"],
    marker = ["hex", "square", "cross", "triangle"],
    title = "Crypto Clusters"
)

clusterPlot
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f60b9d8a-c6cf-41ee-a71b-a789a412ce79'>
#   <div id="ef9e0654-9090-4bea-a037-4f1e427aef27" data-root-id="f60b9d8a-c6cf-41ee-a71b-a789a412ce79" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pcaModel = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce to
# three principal components.
pcaData = pcaModel.fit_transform(scaldedMarketData_df)

# View the first five rows of the DataFrame.
pcaData[:5]
# Out:
# array([[-0.60066733,  0.84276006,  0.46159457],
#        [-0.45826071,  0.45846566,  0.95287678],
#        [-0.43306981, -0.16812638, -0.64175193],
#        [-0.47183495, -0.22266008, -0.47905316],
#        [-1.15779997,  2.04120919,  1.85971527]])

# %%
# Retrieve the explained variance to determine how much information
# can be attributed to each principal component.
pcaModel.explained_variance_ratio_
# Out:
# array([0.3719856 , 0.34700813, 0.17603793])

# %%
# dump of features that contributed to the variance ratios
pd.DataFrame(
    pcaModel.components_,
    columns=scaldedMarketData_df.columns,
    index=["PC1", "PC2", "PC3"]
    )
# Out:
#      price_change_percentage_24h  price_change_percentage_7d  \
# PC1                    -0.416728                   -0.102432
# PC2                     0.358162                    0.227432
# PC3                    -0.218795                    0.787670
#
#      price_change_percentage_14d  price_change_percentage_30d  \
# PC1                    -0.009162                     0.191523
# PC2                     0.540415                     0.562182
# PC3                     0.349534                    -0.181744
#
#      price_change_percentage_60d  price_change_percentage_200d  \
# PC1                     0.320365                      0.594468
# PC2                     0.434040                      0.027735
# PC3                    -0.361377                      0.039733
#
#      price_change_percentage_1y
# PC1                    0.568379
# PC2                   -0.150789
# PC3                    0.210541

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:*The first PC is 37%, second is 34%, and third is 17%. This explains ~90% of the variance in the PCA*

# %%
# Create a new DataFrame with the PCA data.
pcaDF = pd.DataFrame(
    pcaData,
    columns=["PC1", "PC2", "PC3"],
    index=scaldedMarketData_df.index
)
# Creating a DataFrame with the PCA data




# Copy the crypto names from the original data
pcaDF["coin_id"] = scaldedMarketData_df.index

# Set the coinid column as index
pcaDF = pcaDF.set_index("coin_id")

# Display sample data
pcaDF.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
kValues = list(range(1,11))

# %%
# Create an empty list to store the inertia values
inertiaValues = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list
for k in kValues:
    model = KMeans(n_clusters=k, random_state=0, n_init='auto')
    model.fit(pcaDF)
    inertiaValues.append(model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbowData = {
    "k": kValues,
    "inertia": inertiaValues
}

# Create a DataFrame with the data to plot the Elbow curve
PCAelbow_df = pd.DataFrame(elbowData)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
hvplot.extension('bokeh')

pcaElbowPlot = PCAelbow_df.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve using PCA Data",
    xticks=kValues,
)

pcaElbowPlot
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2ac4d704-a334-49d3-b78e-23998adb16ff'>
#   <div id="bcea19ef-4719-4159-a03e-6fa9fb6de0c8" data-root-id="2ac4d704-a334-49d3-b78e-23998adb16ff" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:*The best value for 'k' when using PCA data is '4'*
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:*This does not differ from our prior K Value*

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
pcaKModel = KMeans(n_clusters=4, n_init='auto')

# %%
# Fit the K-Means model using the PCA data
pcaKModel.fit(pcaDF)
# Out:
# KMeans(n_clusters=4)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
pcaPredictions = pcaKModel.predict(pcaDF)

# Print the resulting array of cluster values.
pcaPredictions
# Out:
# array([0, 0, 3, 3, 0, 0, 0, 0, 0, 3, 3, 3, 3, 0, 3, 0, 3, 3, 0, 3, 3, 0,
#        3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 2, 0, 3, 3, 1, 3, 3, 3, 3],
#       dtype=int32)

# %%
# Create a copy of the DataFrame with the PCA data
pcapreictions_df = pcaDF.copy()

# Add a new column to the DataFrame with the predicted clusters
pcapreictions_df['cryptoCluster'] = pcaPredictions

# Display sample data
pcapreictions_df.head()
# Out:
#                    PC1       PC2       PC3  cryptoCluster
# coin_id
# bitcoin      -0.600667  0.842760  0.461595              0
# ethereum     -0.458261  0.458466  0.952877              0
# tether       -0.433070 -0.168126 -0.641752              3
# ripple       -0.471835 -0.222660 -0.479053              3
# bitcoin-cash -1.157800  2.041209  1.859715              0

# %%
# Create a scatter plot using hvPlot by setting
# `x="PC1"` and `y="PC2"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
hvplot.extension('bokeh')

clusterPCAPlot = pcapreictions_df.hvplot.scatter(
    x="PC1",
    y="PC2",
    by="cryptoCluster",
    hover_cols=["coin_id"],
    marker = ["hex", "square", "cross", "triangle"],
    title = "Crypto Clusters using PCA"
)

clusterPCAPlot
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='9a34303a-94a1-46fa-afc6-d9f9d4c19603'>
#   <div id="ca7d1121-9008-4670-8b24-08647d90d5a9" data-root-id="9a34303a-94a1-46fa-afc6-d9f9d4c19603" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves
hvplot.extension('bokeh')

elbowPlot + pcaElbowPlot
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='fa9c8910-af22-45be-a1a3-936e293ad1ee'>
#   <div id="b9ccd292-9fd0-4f7a-af7d-4dbee7b741b9" data-root-id="fa9c8910-af22-45be-a1a3-936e293ad1ee" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Composite plot to contrast the clusters
hvplot.extension('bokeh')

clusterPlot + clusterPCAPlot
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f2453a8f-738c-496a-b8f8-0572fff867a7'>
#   <div id="b384f266-9b64-4d2a-afc4-b93397654378" data-root-id="f2453a8f-738c-496a-b8f8-0572fff867a7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:*By using fewer features, we can conclude that we can get a similar performance on the model since we still identify four clusters. *
